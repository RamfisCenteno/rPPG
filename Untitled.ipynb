# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_array = np.load('pulse.npy')
data = pd.DataFrame(data_array, columns = ['BVP'])

# %%
data
# Out:
#           BVP
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000000
# ..        ...
# 995 -0.192721
# 996 -0.186318
# 997 -0.155214
# 998 -0.118679
# 999 -0.080248
#
# [1000 rows x 1 columns]

# %%
data['time'] = np.arange(0, (len(data)*.1), 0.1)

# %%
data
# Out:
#           BVP  time
# 0    0.000000   0.0
# 1    0.000000   0.1
# 2    0.000000   0.2
# 3    0.000000   0.3
# 4    0.000000   0.4
# ..        ...   ...
# 995 -0.192721  99.5
# 996 -0.186318  99.6
# 997 -0.155214  99.7
# 998 -0.118679  99.8
# 999 -0.080248  99.9
#
# [1000 rows x 2 columns]

# %%
data['hrv'] = (data['BVP'].diff())/0.04

# %%
data
# Out:
#           BVP  time       hrv
# 0    0.000000   0.0       NaN
# 1    0.000000   0.1  0.000000
# 2    0.000000   0.2  0.000000
# 3    0.000000   0.3  0.000000
# 4    0.000000   0.4  0.000000
# ..        ...   ...       ...
# 995 -0.192721  99.5 -0.116028
# 996 -0.186318  99.6  0.160092
# 997 -0.155214  99.7  0.777599
# 998 -0.118679  99.8  0.913353
# 999 -0.080248  99.9  0.960796
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(20, 14), dpi=80)
plt.plot(data['BVP'])
# plt.xlim(210,280)

# %%
plt.figure(figsize=(20, 14), dpi=80)
plt.plot(data['hrv'])
